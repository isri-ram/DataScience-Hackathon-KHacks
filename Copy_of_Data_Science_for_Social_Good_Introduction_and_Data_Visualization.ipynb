# %% [markdown]
# ![gcr.png](data:image/png;base64,...)

# %% [markdown]
# # Introducing Pandas Objects

# %% [markdown]
# At the very basic level, Pandas objects can be thought of as enhanced versions of NumPy structured arrays in which the rows and columns are identified with labels rather than simple integer indices.
# As we will see during the course of this chapter, Pandas provides a host of useful tools, methods, and functionality on top of the basic data structures, but nearly everything that follows will require an understanding of what these structures are.
# Thus, before we go any further, let's introduce these three fundamental Pandas data structures: the ``Series``, ``DataFrame``, and ``Index``.
#
# We will start our code sessions with the standard NumPy and Pandas imports:

# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount = True)
# Out:
# Mounted at /content/drive

# %%
#For temporary storage directly upload the file on colab
path = 'drive/My Drive/Colab Notebooks/Toyota - Toyota.csv'
import pandas as pd
#Can write the path directly as well
df = pd.read_csv(path)
print(type(df))
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
#      Price  Age     KM FuelType   HP  MetColor  Automatic    CC  Doors  Weight
# 0    13500   23  46986   Diesel   90         1          0  2000      3    1165
# 1    13750   23  72937   Diesel   90         1          0  2000      3    1165
# 2    13950   24  41711   Diesel   90         1          0  2000      3    1165
# 3    14950   26  48000   Diesel   90         0          0  2000      3    1165
# 4    13750   30  38500   Diesel   90         0          0  2000      3    1170
# ..     ...  ...    ...      ...  ...       ...        ...   ...    ...     ...
# 494  11950   54  58745   Petrol  110         1          0  1600      4    1035
# 495  11250   52  58596   Petrol  110         1          0  1600      3    1045
# 496  11750   54  58530   Petrol  110         0          0  1600      5    1075
# 497  10950   55  58377   Petrol  110         1          0  1600      3    1050
# 498  11250   56  58142   Petrol  110         1          0  1600      5    1080
#
# [499 rows x 10 columns]

# %%
#NaN - Not a Number
df = pd.read_csv(path, index_col = 0, na_values=['??', '????'])
#Here unnnamed col got removed and all the ?? and ???? got changed to NaN

# %%
#To read all values -> (all), dont forget the bracket
print(df.to_string())

# %%
#To read only first 5 rows
df.head()
#To read only last 5 rows
df.tail()

# %%
#row numbers/names dont write index()
df.index

# %%
#column numbers/names dont write columns()
df.columns

# %% [markdown]
# # Data Manipulation on Toyota.csv

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount = True)
# Out:
# Mounted at /content/drive

# %%
path = 'drive/My Drive/Colab Notebooks/Toyota - Toyota.csv'
import pandas as pd
df = pd.read_csv(path,  na_values=['??', '????'])

# %% [markdown]
# Question 1: Find maximum value in a KM column and the minimum value in
#
# weight column

# %%
KM = df['KM']
print(f'Maximum value in KM column: {max(KM)}')
weight = df['Weight']
print(f'Minimum value in weight column: {min(weight)}')
# Out:
# Maximum value in KM column: 243000
# Minimum value in weight column: 1015

# %% [markdown]
# Question 2: Find the mean and median of CC column

# %%
cc = df['CC']
mean = cc.mean()
median = cc.median()
print(f'CC Mean: {mean}')
print(f'CC Median: {median}')
# Out:
# CC Mean: 1610.3587174348697
# CC Median: 1600.0

# %% [markdown]
# Question 3: Create the new column ‘Current Price ‘with value Current Price = (Price*2) +100

# %%
df['Current Price'] = (df['Price'] * 2) + 100
df
# Out:
#      Price  Age     KM FuelType   HP  MetColor  Automatic    CC  Doors  \
# 0    13500   23  46986   Diesel   90         1          0  2000      3
# 1    13750   23  72937   Diesel   90         1          0  2000      3
# 2    13950   24  41711   Diesel   90         1          0  2000      3
# 3    14950   26  48000   Diesel   90         0          0  2000      3
# 4    13750   30  38500   Diesel   90         0          0  2000      3
# ..     ...  ...    ...      ...  ...       ...        ...   ...    ...
# 494  11950   54  58745   Petrol  110         1          0  1600      4
# 495  11250   52  58596   Petrol  110         1          0  1600      3
# 496  11750   54  58530   Petrol  110         0          0  1600      5
# 497  10950   55  58377   Petrol  110         1          0  1600      3
# 498  11250   56  58142   Petrol  110         1          0  1600      5
#
#      Weight  Current Price
# 0      1165          27100
# 1      1165          27600
# 2      1165          28000
# 3      1165          30000
# 4      1170          27600
# ..      ...            ...
# 494    1035          24000
# 495    1045          22600
# 496    1075          23600
# 497    1050          22000
# 498    1080          22600
#
# [499 rows x 11 columns]

# %% [markdown]
# Question 4: Display the first 50 Price, Age and CC such that age in ascending order

# %%
first_50 = df.head(50)
first_50.sort_values(by=['Age'], ascending=False)
first_50[['Age', 'Price','CC']]
# Out:
#     Age  Price    CC
# 0    23  13500  2000
# 1    23  13750  2000
# 2    24  13950  2000
# 3    26  14950  2000
# 4    30  13750  2000
# 5    32  12950  2000
# 6    27  16900  2000
# 7    30  18600  2000
# 8    27  21500  1800
# 9    23  12950  1900
# 10   25  20950  1800
# 11   22  19950  1800
# 12   25  19600  1800
# 13   31  21500  1800
# 14   32  22500  1800
# 15   28  22000  1800
# 16   30  22750  1800
# 17   24  17950  1600
# 18   24  16750  1600
# 19   30  16950  1600
# 20   30  15950  1600
# 21   29  16950  1600
# 22   28  15950  1600
# 23   28  16950  1600
# 24   29  16250  1600
# 25   25  15950  1600
# 26   27  17495  1600
# 27   29  15750  1600
# 28   28  16950  1600
# 29   30  17950  1600
# 30   29  12950  1400
# 31   22  15750  1400
# 32   27  15950  1400
# 33   26  14950  1400
# 34   22  15500  1400
# 35   26  15750  1400
# 36   25  15950  1400
# 37   23  14950  1400
# 38   32  15750  1400
# 39   27  14750  1400
# 40   22  13950  1400
# 41   27  16750  1400
# 42   22  13950  1400
# 43   27  16950  2000
# 44   22  16950  2000
# 45   23  19000  2000
# 46   27  17950  2000
# 47   22  15800  1400
# 48   22  17950  2000
# 49   31  21950  1800

# %% [markdown]
# Question 5: Group the data frame by Fuel Type and Metal Colour

# %%
groups = df.groupby(['FuelType','MetColor'])
groups.first()
# Out:
#                    Price  Age      KM   HP  Automatic    CC  Doors  Weight  \
# FuelType MetColor
# CNG      0          7750   43  178858  110          0  1600      3    1084
#          1         11950   39   98823  110          0  1600      5    1119
# Diesel   0         14950   26   48000   90          0  2000      3    1165
#          1         13500   23   46986   90          0  2000      3    1165
# Petrol   0         21500   27   19700  192          0  1800      3    1185
#          1         21500   31   23000  192          0  1800      3    1185
#
#                    Current Price
# FuelType MetColor
# CNG      0                 15600
#          1                 24000
# Diesel   0                 30000
#          1                 27100
# Petrol   0                 43100
#          1                 43100

# %% [markdown]
# Question 6: Count the null values in the data frame and fill the null values in CC column by ‘0’

# %%
import numpy as np
count_nan = df.isna().sum().sum()
print(f'The total number of null values: {count_nan}')
cc = df['CC']
cc.replace(np.nan,0)
# Out:
# The total number of null values: 0
# 0      2000
# 1      2000
# 2      2000
# 3      2000
# 4      2000
#        ...
# 494    1600
# 495    1600
# 496    1600
# 497    1600
# 498    1600
# Name: CC, Length: 499, dtype: int64

# %% [markdown]
# Question 7: Append 3 new rows in the data frame and display it

# %%
temp = df
#if we write only temp.append then it doesnt work
temp = temp.append({'Price': 9000, 'Age': 33.0, 'KM': 789.09, 'FuelType': 'Petrol', 'HP': 110.0, 'MetColor': 1.0, 'Automatic': 0, 'CC': 1700, 'Doors': 4, 'Weight': 1040, 'Current Price': 22220}, ignore_index = True)
temp = temp.append({'Price': 8000, 'Age': 12.0, 'KM': 423.59, 'FuelType': 'Petrol', 'HP': 111.0, 'MetColor': 0.0, 'Automatic': 0, 'CC': 1600, 'Doors': 3, 'Weight': 1450, 'Current Price': 67220}, ignore_index = True)
temp = temp.append({'Price': 7000, 'Age': 37.0, 'KM': 459.09, 'FuelType': 'Petrol', 'HP': 112.0, 'MetColor': 2.0, 'Automatic': 0, 'CC': 1500, 'Doors': 2, 'Weight': 1500, 'Current Price': 27220}, ignore_index = True)
temp.tail()
# Out:
#      Price   Age        KM FuelType     HP  MetColor  Automatic    CC  Doors  \
# 497  10950  55.0  58377.00   Petrol  110.0       1.0          0  1600      3
# 498  11250  56.0  58142.00   Petrol  110.0       1.0          0  1600      5
# 499   9000  33.0    789.09   Petrol  110.0       1.0          0  1700      4
# 500   8000  12.0    423.59   Petrol  111.0       0.0          0  1600      3
# 501   7000  37.0    459.09   Petrol  112.0       2.0          0  1500      2
#
#      Weight  Current Price
# 497    1050          22000
# 498    1080          22600
# 499    1040          22220
# 500    1450          67220
# 501    1500          27220

# %% [markdown]
# Question 8: Drop the HP column in the data frame and display it

# %%
temp = df.copy()
temp.drop(['Price'], axis = 1)
price = df['Price']
price
temp['Price'] = price
temp
# Out:
#      Price  Age     KM FuelType   HP  MetColor  Automatic    CC  Doors  \
# 0    13500   23  46986   Diesel   90         1          0  2000      3
# 1    13750   23  72937   Diesel   90         1          0  2000      3
# 2    13950   24  41711   Diesel   90         1          0  2000      3
# 3    14950   26  48000   Diesel   90         0          0  2000      3
# 4    13750   30  38500   Diesel   90         0          0  2000      3
# ..     ...  ...    ...      ...  ...       ...        ...   ...    ...
# 494  11950   54  58745   Petrol  110         1          0  1600      4
# 495  11250   52  58596   Petrol  110         1          0  1600      3
# 496  11750   54  58530   Petrol  110         0          0  1600      5
# 497  10950   55  58377   Petrol  110         1          0  1600      3
# 498  11250   56  58142   Petrol  110         1          0  1600      5
#
#      Weight  Current Price
# 0      1165          27100
# 1      1165          27600
# 2      1165          28000
# 3      1165          30000
# 4      1170          27600
# ..      ...            ...
# 494    1035          24000
# 495    1045          22600
# 496    1075          23600
# 497    1050          22000
# 498    1080          22600
#
# [499 rows x 11 columns]

# %% [markdown]
# Question 9: Drop the 50th and 100th row in the data frame

# %%
temp.drop([50, 100], axis = 0)
# Out:
#      Price  Age     KM FuelType   HP  MetColor  Automatic    CC  Doors  \
# 0    13500   23  46986   Diesel   90         1          0  2000      3
# 1    13750   23  72937   Diesel   90         1          0  2000      3
# 2    13950   24  41711   Diesel   90         1          0  2000      3
# 3    14950   26  48000   Diesel   90         0          0  2000      3
# 4    13750   30  38500   Diesel   90         0          0  2000      3
# ..     ...  ...    ...      ...  ...       ...        ...   ...    ...
# 494  11950   54  58745   Petrol  110         1          0  1600      4
# 495  11250   52  58596   Petrol  110         1          0  1600      3
# 496  11750   54  58530   Petrol  110         0          0  1600      5
# 497  10950   55  58377   Petrol  110         1          0  1600      3
# 498  11250   56  58142   Petrol  110         1          0  1600      5
#
#      Weight  Current Price
# 0      1165          27100
# 1      1165          27600
# 2      1165          28000
# 3      1165          30000
# 4      1170          27600
# ..      ...            ...
# 494    1035          24000
# 495    1045          22600
# 496    1075          23600
# 497    1050          22000
# 498    1080          22600
#
# [497 rows x 11 columns]

# %% [markdown]
# Question 10: Display the price, KM and HP of first 100 values with 'CC' greater than 1600

# %%
df_filtered = df[df['CC'] > 1600].head(100)
print(df_filtered[['Price', 'KM', 'HP']])
# Out:
#      Price     KM  HP
# 0    13500  46986  90
# 1    13750  72937  90
# 2    13950  41711  90
# 3    14950  48000  90
# 4    13750  38500  90
# ..     ...    ...  ..
# 458   8695  70440  69
# 463   8750  69000  69
# 465  11450  68520  72
# 480  11500  63000  69
# 487   8950  61000  69
#
# [92 rows x 3 columns]

# %% [markdown]
# # Exploratory Data Analysis on Employee Data

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount = True)
# Out:
# Mounted at /content/drive

# %%
path='drive/My Drive/Colab Notebooks/Emp_EDA - Emp_EDA.csv'
#For temporary storage directly upload the file on colab
import pandas as pd
#Can write the path directly as well
df = pd.read_csv(path)
df
# Out:
#    First Name  Gender  Salary                  Team   Age  Experience  \
# 0       Maria  Female  130590               Finance   NaN           5
# 1      Angela  Female   54568  Business Development  27.0           5
# 2       Allan    Male  125792       Client Services  28.0           6
# 3       Rohan  Female   45906               Finance  28.0           7
# 4     Douglas    Male   97308             Marketing  28.0           7
# 5     Brandon    Male  112807       Human Resources  30.0           8
# 6       Diana  Female  132940       Client Services  31.0           9
# 7     Frances     NaN  139852  Business Development  34.0          10
# 8     Matthew    Male  100612             Marketing  34.0          10
# 9       Larry    Male  101004       Client Services  35.0          11
# 10     Joshua    Male   90816       Client Services  35.0          11
# 11      Jerry    Male   72000               Finance  35.0          12
# 12       Lois  Female   64714                 Legal  35.0          12
# 13     Dennis    Male  115163                 Legal  36.0          13
# 14       John    Male   97950       Client Services  37.0          13
# 15     Thomas    Male   61933             Marketing  38.0          14
# 16      Shawn    Male  111737       Human Resources  39.0          15
# 17       Gary    Male  109831               Product  39.0          15
# 18     Jeremy    Male   90370       Human Resources  42.0          18
# 19   Kimberly  Female   41426               Finance  44.0          20
# 20     Louise  Female   63241  Business Development  45.0          21
# 21      Donna  Female   81014               Product  49.0          23
# 22       Ruby  Female   65476               Product  54.0          25
# 23    Lillian  Female   59414               Product  55.0          26
# 24    Lillian  Female   59414               Product  55.0          26
#
#       New_Salary  Bonus  Senior Management
# 0   146075.36220  20000              False
# 1    64675.63064  19000               True
# 2   132134.43260  18500              False
# 3    51230.17788  18000               True
# 4   104066.04060  17000               True
# 5   132539.20040  16000               True
# 6   158307.61080  15800              False
# 7   150374.46450  15500               True
# 8   114340.50740  15000              False
# 9   102406.94560  14700               True
# 10  107903.93860  14300               True
# 11   78724.80000  14000               True
# 12   67906.98876  14000               True
# 13  126823.25380  13000              False
# 14  111538.60350  12000              False
# 15   68711.56685  11900               True
# 16  118903.81120  11500              False
# 17  116235.24560  11500              False
# 18   97029.36530  11000              False
# 19   44512.23700  11000               True
# 20   72810.62812  10800               True
# 21   82548.40516  10600              False
# 22   72031.45712  10400               True
# 23   60160.23984  10300              False
# 24   60160.23984  10300               True

# %% [markdown]
# 1. Remove the irrelevant column &#39;Senior Management&#39; (inplace=True)

# %%
df.pop('Senior Management')
df
# Out:
#    First Name  Gender  Salary                  Team   Age  Experience  \
# 0       Maria  Female  130590               Finance   NaN           5
# 1      Angela  Female   54568  Business Development  27.0           5
# 2       Allan    Male  125792       Client Services  28.0           6
# 3       Rohan  Female   45906               Finance  28.0           7
# 4     Douglas    Male   97308             Marketing  28.0           7
# 5     Brandon    Male  112807       Human Resources  30.0           8
# 6       Diana  Female  132940       Client Services  31.0           9
# 7     Frances     NaN  139852  Business Development  34.0          10
# 8     Matthew    Male  100612             Marketing  34.0          10
# 9       Larry    Male  101004       Client Services  35.0          11
# 10     Joshua    Male   90816       Client Services  35.0          11
# 11      Jerry    Male   72000               Finance  35.0          12
# 12       Lois  Female   64714                 Legal  35.0          12
# 13     Dennis    Male  115163                 Legal  36.0          13
# 14       John    Male   97950       Client Services  37.0          13
# 15     Thomas    Male   61933             Marketing  38.0          14
# 16      Shawn    Male  111737       Human Resources  39.0          15
# 17       Gary    Male  109831               Product  39.0          15
# 18     Jeremy    Male   90370       Human Resources  42.0          18
# 19   Kimberly  Female   41426               Finance  44.0          20
# 20     Louise  Female   63241  Business Development  45.0          21
# 21      Donna  Female   81014               Product  49.0          23
# 22       Ruby  Female   65476               Product  54.0          25
# 23    Lillian  Female   59414               Product  55.0          26
# 24    Lillian  Female   59414               Product  55.0          26
#
#       New_Salary  Bonus
# 0   146075.36220  20000
# 1    64675.63064  19000
# 2   132134.43260  18500
# 3    51230.17788  18000
# 4   104066.04060  17000
# 5   132539.20040  16000
# 6   158307.61080  15800
# 7   150374.46450  15500
# 8   114340.50740  15000
# 9   102406.94560  14700
# 10  107903.93860  14300
# 11   78724.80000  14000
# 12   67906.98876  14000
# 13  126823.25380  13000
# 14  111538.60350  12000
# 15   68711.56685  11900
# 16  118903.81120  11500
# 17  116235.24560  11500
# 18   97029.36530  11000
# 19   44512.23700  11000
# 20   72810.62812  10800
# 21   82548.40516  10600
# 22   72031.45712  10400
# 23   60160.23984  10300
# 24   60160.23984  10300

# %% [markdown]
# 2. Remove the duplicate rows and analyze

# %%
df.drop_duplicates(subset='First Name',keep='first',inplace=True)
df
# Out:
#    First Name  Gender  Salary                  Team   Age  Experience  \
# 0       Maria  Female  130590               Finance   NaN           5
# 1      Angela  Female   54568  Business Development  27.0           5
# 2       Allan    Male  125792       Client Services  28.0           6
# 3       Rohan  Female   45906               Finance  28.0           7
# 4     Douglas    Male   97308             Marketing  28.0           7
# 5     Brandon    Male  112807       Human Resources  30.0           8
# 6       Diana  Female  132940       Client Services  31.0           9
# 7     Frances     NaN  139852  Business Development  34.0          10
# 8     Matthew    Male  100612             Marketing  34.0          10
# 9       Larry    Male  101004       Client Services  35.0          11
# 10     Joshua    Male   90816       Client Services  35.0          11
# 11      Jerry    Male   72000               Finance  35.0          12
# 12       Lois  Female   64714                 Legal  35.0          12
# 13     Dennis    Male  115163                 Legal  36.0          13
# 14       John    Male   97950       Client Services  37.0          13
# 15     Thomas    Male   61933             Marketing  38.0          14
# 16      Shawn    Male  111737       Human Resources  39.0          15
# 17       Gary    Male  109831               Product  39.0          15
# 18     Jeremy    Male   90370       Human Resources  42.0          18
# 19   Kimberly  Female   41426               Finance  44.0          20
# 20     Louise  Female   63241  Business Development  45.0          21
# 21      Donna  Female   81014               Product  49.0          23
# 22       Ruby  Female   65476               Product  54.0          25
# 23    Lillian  Female   59414               Product  55.0          26
#
#       New_Salary  Bonus
# 0   146075.36220  20000
# 1    64675.63064  19000
# 2   132134.43260  18500
# 3    51230.17788  18000
# 4   104066.04060  17000
# 5   132539.20040  16000
# 6   158307.61080  15800
# 7   150374.46450  15500
# 8   114340.50740  15000
# 9   102406.94560  14700
# 10  107903.93860  14300
# 11   78724.80000  14000
# 12   67906.98876  14000
# 13  126823.25380  13000
# 14  111538.60350  12000
# 15   68711.56685  11900
# 16  118903.81120  11500
# 17  116235.24560  11500
# 18   97029.36530  11000
# 19   44512.23700  11000
# 20   72810.62812  10800
# 21   82548.40516  10600
# 22   72031.45712  10400
# 23   60160.23984  10300

# %% [markdown]
# 3. Rename the column Bonus to Incentive

# %%
df.rename(columns={'Bonus':'Incentive'},inplace=True)
df
# Out:
#    First Name  Gender  Salary                  Team   Age  Experience  \
# 0       Maria  Female  130590               Finance   NaN           5
# 1      Angela  Female   54568  Business Development  27.0           5
# 2       Allan    Male  125792       Client Services  28.0           6
# 3       Rohan  Female   45906               Finance  28.0           7
# 4     Douglas    Male   97308             Marketing  28.0           7
# 5     Brandon    Male  112807       Human Resources  30.0           8
# 6       Diana  Female  132940       Client Services  31.0           9
# 7     Frances     NaN  139852  Business Development  34.0          10
# 8     Matthew    Male  100612             Marketing  34.0          10
# 9       Larry    Male  101004       Client Services  35.0          11
# 10     Joshua    Male   90816       Client Services  35.0          11
# 11      Jerry    Male   72000               Finance  35.0          12
# 12       Lois  Female   64714                 Legal  35.0          12
# 13     Dennis    Male  115163                 Legal  36.0          13
# 14       John    Male   97950       Client Services  37.0          13
# 15     Thomas    Male   61933             Marketing  38.0          14
# 16      Shawn    Male  111737       Human Resources  39.0          15
# 17       Gary    Male  109831               Product  39.0          15
# 18     Jeremy    Male   90370       Human Resources  42.0          18
# 19   Kimberly  Female   41426               Finance  44.0          20
# 20     Louise  Female   63241  Business Development  45.0          21
# 21      Donna  Female   81014               Product  49.0          23
# 22       Ruby  Female   65476               Product  54.0          25
# 23    Lillian  Female   59414               Product  55.0          26
#
#       New_Salary  Incentive
# 0   146075.36220      20000
# 1    64675.63064      19000
# 2   132134.43260      18500
# 3    51230.17788      18000
# 4   104066.04060      17000
# 5   132539.20040      16000
# 6   158307.61080      15800
# 7   150374.46450      15500
# 8   114340.50740      15000
# 9   102406.94560      14700
# 10  107903.93860      14300
# 11   78724.80000      14000
# 12   67906.98876      14000
# 13  126823.25380      13000
# 14  111538.60350      12000
# 15   68711.56685      11900
# 16  118903.81120      11500
# 17  116235.24560      11500
# 18   97029.36530      11000
# 19   44512.23700      11000
# 20   72810.62812      10800
# 21   82548.40516      10600
# 22   72031.45712      10400
# 23   60160.23984      10300

# %% [markdown]
# 4. Calculate the central tendency measures for &#39;Experience&#39;

# %%
print('Mean',df['Experience'].mean())
print('Median',df['Experience'].median())
print('Mode',df['Experience'].mode())
# Out:
# Mean 13.166666666666666
# Median 12.0
# Mode 0     5
# 1     7
# 2    10
# 3    11
# 4    12
# 5    13
# 6    15
# dtype: int64

# %% [markdown]
# 5. Calculate the variability measures for &#39;Experience&#39;

# %%
min=df['Experience'].min()
max=df['Experience'].max()
print(min,max)
print('Range',max-min)
print('var',df['Experience'].var())
print('std',df['Experience'].std())
# Out:
# 5 26
# Range 21
# var 38.14492753623188
# std 6.176157991521257

# %% [markdown]
# 6. Calculate the IQR using quantile for &#39;Experience&#39;

# %%
Q1=df['Experience'].quantile(.25)
Q3=df['Experience'].quantile(.75)
print('IQR',Q3-Q1)
# Out:
# IQR 7.0

# %% [markdown]
# 7. Calculate the z-score for &#39;Experience’

# %%
import scipy.stats as stats
Zscore=stats.zscore(df['Experience'])
print('Zscore',Zscore)
# Out:
# Zscore 0    -1.350729
# 1    -1.350729
# 2    -1.185333
# 3    -1.019938
# 4    -1.019938
# 5    -0.854543
# 6    -0.689147
# 7    -0.523752
# 8    -0.523752
# 9    -0.358357
# 10   -0.358357
# 11   -0.192961
# 12   -0.192961
# 13   -0.027566
# 14   -0.027566
# 15    0.137829
# 16    0.303225
# 17    0.303225
# 18    0.799411
# 19    1.130202
# 20    1.295597
# 21    1.626388
# 22    1.957178
# 23    2.122574
# Name: Experience, dtype: float64

# %% [markdown]
# 8. Add 2 rows at the end of the dataframe with the given values
# {&#39;First Name&#39;:&#39;Zion&#39;, &#39;Gender&#39;:&#39;Male&#39;, &#39;Team&#39;:&#39;Finance&#39;, &#39;Age&#39;:37,
# &#39;Experience&#39;:90,&#39;New_Salary&#39;:146075.4, &#39;Incentive&#39;:20000
# {&#39;First Name&#39;:&#39;Frances&#39;, &#39;Gender&#39;:&#39;Male&#39;, &#39;Salary&#39;:139852, &#39;Team&#39;:&#39;Business
# Development&#39;, &#39;Age&#39;:34, &#39;Experience&#39;:95, &#39;New_Salary&#39;:150374.5, &#39;Incentive&#39;:15500

# %%
df1={'First Name':'Zion', 'Gender':'Male', 'Team':'Finance', 'Age':37, 'Experience':90,'New_Salary':146075.4, 'Incentive':20000 }
df2= {'First Name':'Frances', 'Gender':'Male', 'Salary':139852, 'Team':'Business Development', 'Age':34, 'Experience':95, 'New_Salary':150374.5, 'Incentive':15500}
df=df.append(df1,ignore_index=True)
df=df.append(df2,ignore_index=True)
#df.tail()
df
# Out:
#    First Name  Gender    Salary                  Team   Age  Experience  \
# 0       Maria  Female  130590.0               Finance   NaN           5
# 1      Angela  Female   54568.0  Business Development  27.0           5
# 2       Allan    Male  125792.0       Client Services  28.0           6
# 3       Rohan  Female   45906.0               Finance  28.0           7
# 4     Douglas    Male   97308.0             Marketing  28.0           7
# 5     Brandon    Male  112807.0       Human Resources  30.0           8
# 6       Diana  Female  132940.0       Client Services  31.0           9
# 7     Frances     NaN  139852.0  Business Development  34.0          10
# 8     Matthew    Male  100612.0             Marketing  34.0          10
# 9       Larry    Male  101004.0       Client Services  35.0          11
# 10     Joshua    Male   90816.0       Client Services  35.0          11
# 11      Jerry    Male   72000.0               Finance  35.0          12
# 12       Lois  Female   64714.0                 Legal  35.0          12
# 13     Dennis    Male  115163.0                 Legal  36.0          13
# 14       John    Male   97950.0       Client Services  37.0          13
# 15     Thomas    Male   61933.0             Marketing  38.0          14
# 16      Shawn    Male  111737.0       Human Resources  39.0          15
# 17       Gary    Male  109831.0               Product  39.0          15
# 18     Jeremy    Male   90370.0       Human Resources  42.0          18
# 19   Kimberly  Female   41426.0               Finance  44.0          20
# 20     Louise  Female   63241.0  Business Development  45.0          21
# 21      Donna  Female   81014.0               Product  49.0          23
# 22       Ruby  Female   65476.0               Product  54.0          25
# 23    Lillian  Female   59414.0               Product  55.0          26
# 24       Zion    Male       NaN               Finance  37.0          90
# 25    Frances    Male  139852.0  Business Development  34.0          95
#
#       New_Salary  Incentive
# 0   146075.36220      20000
# 1    64675.63064      19000
# 2   132134.43260      18500
# 3    51230.17788      18000
# 4   104066.04060      17000
# 5   132539.20040      16000
# 6   158307.61080      15800
# 7   150374.46450      15500
# 8   114340.50740      15000
# 9   102406.94560      14700
# 10  107903.93860      14300
# 11   78724.80000      14000
# 12   67906.98876      14000
# 13  126823.25380      13000
# 14  111538.60350      12000
# 15   68711.56685      11900
# 16  118903.81120      11500
# 17  116235.24560      11500
# 18   97029.36530      11000
# 19   44512.23700      11000
# 20   72810.62812      10800
# 21   82548.40516      10600
# 22   72031.45712      10400
# 23   60160.23984      10300
# 24  146075.40000      20000
# 25  150374.50000      15500

# %% [markdown]
# 9. Replace nan value with given value (Salary=130590)

# %%
import numpy as np
df['Salary'].replace(to_replace=np.nan,value=130590,inplace =True)
df
# Out:
#    First Name  Gender    Salary                  Team   Age  Experience  \
# 0       Maria  Female  130590.0               Finance   NaN           5
# 1      Angela  Female   54568.0  Business Development  27.0           5
# 2       Allan    Male  125792.0       Client Services  28.0           6
# 3       Rohan  Female   45906.0               Finance  28.0           7
# 4     Douglas    Male   97308.0             Marketing  28.0           7
# 5     Brandon    Male  112807.0       Human Resources  30.0           8
# 6       Diana  Female  132940.0       Client Services  31.0           9
# 7     Frances     NaN  139852.0  Business Development  34.0          10
# 8     Matthew    Male  100612.0             Marketing  34.0          10
# 9       Larry    Male  101004.0       Client Services  35.0          11
# 10     Joshua    Male   90816.0       Client Services  35.0          11
# 11      Jerry    Male   72000.0               Finance  35.0          12
# 12       Lois  Female   64714.0                 Legal  35.0          12
# 13     Dennis    Male  115163.0                 Legal  36.0          13
# 14       John    Male   97950.0       Client Services  37.0          13
# 15     Thomas    Male   61933.0             Marketing  38.0          14
# 16      Shawn    Male  111737.0       Human Resources  39.0          15
# 17       Gary    Male  109831.0               Product  39.0          15
# 18     Jeremy    Male   90370.0       Human Resources  42.0          18
# 19   Kimberly  Female   41426.0               Finance  44.0          20
# 20     Louise  Female   63241.0  Business Development  45.0          21
# 21      Donna  Female   81014.0               Product  49.0          23
# 22       Ruby  Female   65476.0               Product  54.0          25
# 23    Lillian  Female   59414.0               Product  55.0          26
# 24       Zion    Male  130590.0               Finance  37.0          90
# 25    Frances    Male  139852.0  Business Development  34.0          95
#
#       New_Salary  Incentive
# 0   146075.36220      20000
# 1    64675.63064      19000
# 2   132134.43260      18500
# 3    51230.17788      18000
# 4   104066.04060      17000
# 5   132539.20040      16000
# 6   158307.61080      15800
# 7   150374.46450      15500
# 8   114340.50740      15000
# 9   102406.94560      14700
# 10  107903.93860      14300
# 11   78724.80000      14000
# 12   67906.98876      14000
# 13  126823.25380      13000
# 14  111538.60350      12000
# 15   68711.56685      11900
# 16  118903.81120      11500
# 17  116235.24560      11500
# 18   97029.36530      11000
# 19   44512.23700      11000
# 20   72810.62812      10800
# 21   82548.40516      10600
# 22   72031.45712      10400
# 23   60160.23984      10300
# 24  146075.40000      20000
# 25  150374.50000      15500

# %% [markdown]
# 10. Replace the nan value in Slary Column with previous value, next value, linear
# interpolation and central tendency measures.

# %%
#replacing with the previous value
df['Salary'].fillna(method="ffill")
df
# Out:
#    First Name  Gender    Salary                  Team   Age  Experience  \
# 0       Maria  Female  130590.0               Finance   NaN           5
# 1      Angela  Female   54568.0  Business Development  27.0           5
# 2       Allan    Male  125792.0       Client Services  28.0           6
# 3       Rohan  Female   45906.0               Finance  28.0           7
# 4     Douglas    Male   97308.0             Marketing  28.0           7
# 5     Brandon    Male  112807.0       Human Resources  30.0           8
# 6       Diana  Female  132940.0       Client Services  31.0           9
# 7     Frances     NaN  139852.0  Business Development  34.0          10
# 8     Matthew    Male  100612.0             Marketing  34.0          10
# 9       Larry    Male  101004.0       Client Services  35.0          11
# 10     Joshua    Male   90816.0       Client Services  35.0          11
# 11      Jerry    Male   72000.0               Finance  35.0          12
# 12       Lois  Female   64714.0                 Legal  35.0          12
# 13     Dennis    Male  115163.0                 Legal  36.0          13
# 14       John    Male   97950.0       Client Services  37.0          13
# 15     Thomas    Male   61933.0             Marketing  38.0          14
# 16      Shawn    Male  111737.0       Human Resources  39.0          15
# 17       Gary    Male  109831.0               Product  39.0          15
# 18     Jeremy    Male   90370.0       Human Resources  42.0          18
# 19   Kimberly  Female   41426.0               Finance  44.0          20
# 20     Louise  Female   63241.0  Business Development  45.0          21
# 21      Donna  Female   81014.0               Product  49.0          23
# 22       Ruby  Female   65476.0               Product  54.0          25
# 23    Lillian  Female   59414.0               Product  55.0          26
# 24       Zion    Male  130590.0               Finance  37.0          90
# 25    Frances    Male  139852.0  Business Development  34.0          95
#
#       New_Salary  Incentive
# 0   146075.36220      20000
# 1    64675.63064      19000
# 2   132134.43260      18500
# 3    51230.17788      18000
# 4   104066.04060      17000
# 5   132539.20040      16000
# 6   158307.61080      15800
# 7   150374.46450      15500
# 8   114340.50740      15000
# 9   102406.94560      14700
# 10  107903.93860      14300
# 11   78724.80000      14000
# 12   67906.98876      14000
# 13  126823.25380      13000
# 14  111538.60350      12000
# 15   68711.56685      11900
# 16  118903.81120      11500
# 17  116235.24560      11500
# 18   97029.36530      11000
# 19   44512.23700      11000
# 20   72810.62812      10800
# 21   82548.40516      10600
# 22   72031.45712      10400
# 23   60160.23984      10300
# 24  146075.40000      20000
# 25  150374.50000      15500

# %%
#replacing with the next value
df['Salary'].fillna(method="bfill")
df
# Out:
#    First Name  Gender    Salary                  Team   Age  Experience  \
# 0       Maria  Female  130590.0               Finance   NaN           5
# 1      Angela  Female   54568.0  Business Development  27.0           5
# 2       Allan    Male  125792.0       Client Services  28.0           6
# 3       Rohan  Female   45906.0               Finance  28.0           7
# 4     Douglas    Male   97308.0             Marketing  28.0           7
# 5     Brandon    Male  112807.0       Human Resources  30.0           8
# 6       Diana  Female  132940.0       Client Services  31.0           9
# 7     Frances     NaN  139852.0  Business Development  34.0          10
# 8     Matthew    Male  100612.0             Marketing  34.0          10
# 9       Larry    Male  101004.0       Client Services  35.0          11
# 10     Joshua    Male   90816.0       Client Services  35.0          11
# 11      Jerry    Male   72000.0               Finance  35.0          12
# 12       Lois  Female   64714.0                 Legal  35.0          12
# 13     Dennis    Male  115163.0                 Legal  36.0          13
# 14       John    Male   97950.0       Client Services  37.0          13
# 15     Thomas    Male   61933.0             Marketing  38.0          14
# 16      Shawn    Male  111737.0       Human Resources  39.0          15
# 17       Gary    Male  109831.0               Product  39.0          15
# 18     Jeremy    Male   90370.0       Human Resources  42.0          18
# 19   Kimberly  Female   41426.0               Finance  44.0          20
# 20     Louise  Female   63241.0  Business Development  45.0          21
# 21      Donna  Female   81014.0               Product  49.0          23
# 22       Ruby  Female   65476.0               Product  54.0          25
# 23    Lillian  Female   59414.0               Product  55.0          26
# 24       Zion    Male  130590.0               Finance  37.0          90
# 25    Frances    Male  139852.0  Business Development  34.0          95
#
#       New_Salary  Incentive
# 0   146075.36220      20000
# 1    64675.63064      19000
# 2   132134.43260      18500
# 3    51230.17788      18000
# 4   104066.04060      17000
# 5   132539.20040      16000
# 6   158307.61080      15800
# 7   150374.46450      15500
# 8   114340.50740      15000
# 9   102406.94560      14700
# 10  107903.93860      14300
# 11   78724.80000      14000
# 12   67906.98876      14000
# 13  126823.25380      13000
# 14  111538.60350      12000
# 15   68711.56685      11900
# 16  118903.81120      11500
# 17  116235.24560      11500
# 18   97029.36530      11000
# 19   44512.23700      11000
# 20   72810.62812      10800
# 21   82548.40516      10600
# 22   72031.45712      10400
# 23   60160.23984      10300
# 24  146075.40000      20000
# 25  150374.50000      15500

# %%
df['Salary'].interpolate(method='linear',limit_direction='forward')
# Out:
# 0     130590.0
# 1      54568.0
# 2     125792.0
# 3      45906.0
# 4      97308.0
# 5     112807.0
# 6     132940.0
# 7     139852.0
# 8     100612.0
# 9     101004.0
# 10     90816.0
# 11     72000.0
# 12     64714.0
# 13    115163.0
# 14     97950.0
# 15     61933.0
# 16    111737.0
# 17    109831.0
# 18     90370.0
# 19     41426.0
# 20     63241.0
# 21     81014.0
# 22     65476.0
# 23     59414.0
# 24    130590.0
# 25    139852.0
# Name: Salary, dtype: float64

# %%
df.fillna(df['Age'].mean())
# Out:
#    First Name  Gender    Salary                  Team    Age  Experience  \
# 0       Maria  Female  130590.0               Finance  37.16           5
# 1      Angela  Female   54568.0  Business Development  27.00           5
# 2       Allan    Male  125792.0       Client Services  28.00           6
# 3       Rohan  Female   45906.0               Finance  28.00           7
# 4     Douglas    Male   97308.0             Marketing  28.00           7
# 5     Brandon    Male  112807.0       Human Resources  30.00           8
# 6       Diana  Female  132940.0       Client Services  31.00           9
# 7     Frances   37.16  139852.0  Business Development  34.00          10
# 8     Matthew    Male  100612.0             Marketing  34.00          10
# 9       Larry    Male  101004.0       Client Services  35.00          11
# 10     Joshua    Male   90816.0       Client Services  35.00          11
# 11      Jerry    Male   72000.0               Finance  35.00          12
# 12       Lois  Female   64714.0                 Legal  35.00          12
# 13     Dennis    Male  115163.0                 Legal  36.00          13
# 14       John    Male   97950.0       Client Services  37.00          13
# 15     Thomas    Male   61933.0             Marketing  38.00          14
# 16      Shawn    Male  111737.0       Human Resources  39.00          15
# 17       Gary    Male  109831.0               Product  39.00          15
# 18     Jeremy    Male   90370.0       Human Resources  42.00          18
# 19   Kimberly  Female   41426.0               Finance  44.00          20
# 20     Louise  Female   63241.0  Business Development  45.00          21
# 21      Donna  Female   81014.0               Product  49.00          23
# 22       Ruby  Female   65476.0               Product  54.00          25
# 23    Lillian  Female   59414.0               Product  55.00          26
# 24       Zion    Male  130590.0               Finance  37.00          90
# 25    Frances    Male  139852.0  Business Development  34.00          95
#
#       New_Salary  Incentive
# 0   146075.36220      20000
# 1    64675.63064      19000
# 2   132134.43260      18500
# 3    51230.17788      18000
# 4   104066.04060      17000
# 5   132539.20040      16000
# 6   158307.61080      15800
# 7   150374.46450      15500
# 8   114340.50740      15000
# 9   102406.94560      14700
# 10  107903.93860      14300
# 11   78724.80000      14000
# 12   67906.98876      14000
# 13  126823.25380      13000
# 14  111538.60350      12000
# 15   68711.56685      11900
# 16  118903.81120      11500
# 17  116235.24560      11500
# 18   97029.36530      11000
# 19   44512.23700      11000
# 20   72810.62812      10800
# 21   82548.40516      10600
# 22   72031.45712      10400
# 23   60160.23984      10300
# 24  146075.40000      20000
# 25  150374.50000      15500

# %% [markdown]
# 11. Detect the outliers in updated &#39;Experience&#39; with boxplot.

# %%
import seaborn as sns
sns.catplot(x='Experience',kind='box',data=df)
print('Mean',df['Experience'].mean())
print( 'Median' ,df['Experience'].median())
print( 'Mode' ,df[ 'Experience' ].mode())
# Out:
# Mean 19.26923076923077
# Median 12.5
# Mode 0     5
# 1     7
# 2    10
# 3    11
# 4    12
# 5    13
# 6    15
# dtype: int64

# %% [markdown]
# 12. Remove the outliers using IQR by recalculating IQR in updated &#39; Experience &#39; and
# analyse with boxplot

# %%
Ql=df['Experience'].quantile(.25)
Q3=df['Experience'].quantile(.75)
IQR=Q3-Q1
print('IQR',Q3-Q1)
lb=Q1-1.5*IQR

ub=Q3+1.5*IQR

dfout=df[(df['Experience']>lb) & (df['Experience']<ub) ]
dfout.shape
dfout.tail()
sns.catplot(x='Experience',kind='box',data=dfout)
# Out:
# IQR 10.75

# %% [markdown]
# 13. Remove the outliers using z-score by recalculating z-score in updated &#39; Experience &#39;
# and analyse with boxplot

# %%
zscore=stats.zscore(df['Experience'])
print('Zscore',zscore)

filter=((zscore > -1) &(zscore < 2))
newdf=df[filter]
newdf.tail()
sns.catplot(x='Experience',kind='box',data=newdf)
# Out:
# Zscore 0    -0.650540
# 1    -0.650540
# 2    -0.604949
# 3    -0.559359
# 4    -0.559359
# 5    -0.513769
# 6    -0.468178
# 7    -0.422588
# 8    -0.422588
# 9    -0.376998
# 10   -0.376998
# 11   -0.331407
# 12   -0.331407
# 13   -0.285817
# 14   -0.285817
# 15   -0.240226
# 16   -0.194636
# 17   -0.194636
# 18   -0.057865
# 19    0.033316
# 20    0.078906
# 21    0.170087
# 22    0.261268
# 23    0.306858
# 24    3.224644
# 25    3.452596
# Name: Experience, dtype: float64

# %% [markdown]
# 14. Plot the heatmap using the correlation

# %%
import seaborn as sns
t=df[['Incentive','Age','Salary']]
c=t.corr()
sns.heatmap(c,xticklabels=c.columns,annot=True)

# %% [markdown]
# 15. Drop the last two rows added in the dataframe

# %%
df.drop(df.tail(2).index,inplace = True)
df
# Out:
#    First Name  Gender    Salary                  Team   Age  Experience  \
# 0       Maria  Female  130590.0               Finance   NaN           5
# 1      Angela  Female   54568.0  Business Development  27.0           5
# 2       Allan    Male  125792.0       Client Services  28.0           6
# 3       Rohan  Female   45906.0               Finance  28.0           7
# 4     Douglas    Male   97308.0             Marketing  28.0           7
# 5     Brandon    Male  112807.0       Human Resources  30.0           8
# 6       Diana  Female  132940.0       Client Services  31.0           9
# 7     Frances     NaN  139852.0  Business Development  34.0          10
# 8     Matthew    Male  100612.0             Marketing  34.0          10
# 9       Larry    Male  101004.0       Client Services  35.0          11
# 10     Joshua    Male   90816.0       Client Services  35.0          11
# 11      Jerry    Male   72000.0               Finance  35.0          12
# 12       Lois  Female   64714.0                 Legal  35.0          12
# 13     Dennis    Male  115163.0                 Legal  36.0          13
# 14       John    Male   97950.0       Client Services  37.0          13
# 15     Thomas    Male   61933.0             Marketing  38.0          14
# 16      Shawn    Male  111737.0       Human Resources  39.0          15
# 17       Gary    Male  109831.0               Product  39.0          15
# 18     Jeremy    Male   90370.0       Human Resources  42.0          18
# 19   Kimberly  Female   41426.0               Finance  44.0          20
# 20     Louise  Female   63241.0  Business Development  45.0          21
# 21      Donna  Female   81014.0               Product  49.0          23
# 22       Ruby  Female   65476.0               Product  54.0          25
# 23    Lillian  Female   59414.0               Product  55.0          26
#
#       New_Salary  Incentive
# 0   146075.36220      20000
# 1    64675.63064      19000
# 2   132134.43260      18500
# 3    51230.17788      18000
# 4   104066.04060      17000
# 5   132539.20040      16000
# 6   158307.61080      15800
# 7   150374.46450      15500
# 8   114340.50740      15000
# 9   102406.94560      14700
# 10  107903.93860      14300
# 11   78724.80000      14000
# 12   67906.98876      14000
# 13  126823.25380      13000
# 14  111538.60350      12000
# 15   68711.56685      11900
# 16  118903.81120      11500
# 17  116235.24560      11500
# 18   97029.36530      11000
# 19   44512.23700      11000
# 20   72810.62812      10800
# 21   82548.40516      10600
# 22   72031.45712      10400
# 23   60160.23984      10300

# %% [markdown]
# # Data Visualization on Employee Data

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount = True)
# Out:
# Mounted at /content/drive

# %%
path = 'drive/My Drive/Colab Notebooks/Emp_visu - Emp_visu.csv'
import pandas as pd
df = pd.read_csv(path)
df
# Out:
#    First Name  Gender  Salary  Bonus %  Senior Management  \
# 0       Maria  Female  130590   11.858                  0
# 1      Angela  Female   54568   18.523                  1
# 2       Allan    Male  125792    5.042                  0
# 3       Rohan  Female   45906   11.598                  1
# 4     Douglas    Male   97308    6.945                  1
# 5     Brandon    Male  112807   17.492                  1
# 6       Diana  Female  132940   19.082                  0
# 7     Frances  Female  139852    7.524                  1
# 8     Matthew    Male  100612   13.645                  0
# 9       Larry    Male  101004    1.389                  1
# 10     Joshua    Male   90816   18.816                  1
# 11      Jerry    Male   72000    9.340                  1
# 12       Lois  Female   64714    4.934                  1
# 13     Dennis    Male  115163   10.125                  0
# 14       John    Male   97950   13.873                  0
# 15     Thomas    Male   61933   10.945                  1
# 16      Shawn    Male  111737    6.414                  0
# 17       Gary    Male  109831    5.831                  0
# 18     Jeremy    Male   90370    7.369                  0
# 19   Kimberly  Female   41426    7.450                  1
# 20     Louise  Female   63241   15.132                  1
# 21      Donna  Female   81014    1.894                  0
# 22       Ruby  Female   65476   10.012                  1
# 23    Lillian  Female   59414    1.256                  0
# 24      Julie  Female  102508   12.637                  1
#
#                     Team  Age  Experience    New_Salary  Incentive
# 0                Finance   26           5  146075.36220      20000
# 1   Business Development   27           5   64675.63064      19000
# 2        Client Services   28           6  132134.43260      18500
# 3                Finance   28           7   51230.17788      18000
# 4              Marketing   28           7  104066.04060      17000
# 5        Human Resources   30           8  132539.20040      16000
# 6        Client Services   31           9  158307.61080      15800
# 7   Business Development   34          10  150374.46450      15500
# 8              Marketing   34          10  114340.50740      15000
# 9        Client Services   35          11  102406.94560      14700
# 10       Client Services   35          11  107903.93860      14300
# 11               Finance   35          12   78724.80000      14000
# 12                 Legal   35          12   67906.98876      14000
# 13                 Legal   36          13  126823.25380      13000
# 14       Client Services   37          13  111538.60350      12000
# 15             Marketing   38          14   68711.56685      11900
# 16       Human Resources   39          15  118903.81120      11500
# 17               Product   39          15  116235.24560      11500
# 18       Human Resources   42          18   97029.36530      11000
# 19               Finance   44          20   44512.23700      11000
# 20  Business Development   45          21   72810.62812      10800
# 21               Product   49          23   82548.40516      10600
# 22               Product   54          25   72031.45712      10400
# 23               Product   55          26   60160.23984      10300
# 24                 Legal   58          27  115461.93600      10000

# %% [markdown]
# 1. Draw a bar chart with Team and its count (use different colors for each team)

# %%
#bar plot with fuel type with its count(use diff colors for each fuel)
import matplotlib.pyplot as plt
plt.figure(figsize=(12,5))
data = df['Team'].value_counts()
plt.bar(data.index, data.values, color = ['b', 'r', 'y','g','pink','purple', 'orange'])
# Out:
# <BarContainer object of 7 artists>

# %% [markdown]
# 2. Draw a comparative bar chart for Salary and New_Salary against each person (first 15 persons)

# %%
import numpy as np
N = 15
plt.figure(figsize = (15, 15))
#see the spelling of arrange
ind = np.arange(N)
width = 0.25 
xval = df['Salary'].head(15)

bar1 = plt.bar(ind, xval, width, color = 'r')
yval = df['New_Salary'].head(15)
bar2 = plt.bar(ind + width, yval, width, color = 'b')

#comparitive charts should always have legends

plt.xlabel('First Name')
plt.ylabel('Salary')
plt.xticks(ind + width, df['First Name'].head(15))
plt.legend((bar1, bar2),('Salary', 'New_Salary'))

# %% [markdown]
# 3. Draw a horizontal bar chart for Team and Salary

# %%
plt.barh(df['Team'],df['Salary'] )
plt.title("Team vs Salary")
plt.xlabel("Team")
plt.ylabel("Salary")
# Out:
# Text(0, 0.5, 'Salary')

# %% [markdown]
# 4.Draw a stacked bar chart for Salary and New_price against the person (first 10 persons)

# %%
plt.figure(figsize=(9,5))
plt.bar(df['First Name'].head(10), df['Salary'].head(10))
plt.bar(df['First Name'].head(10), df['New_Salary'].head(10), bottom = df['Salary'].head(10))
# Out:
# <BarContainer object of 10 artists>

# %% [markdown]
# 5. Draw a pie chart with Gender and its count

# %%
data = df['Gender'].value_counts()
plt.pie(data.values, labels = data.index, autopct = "%1.1f%%");

# %% [markdown]
# 6. Draw the dot plot between person and experience (first 15 persons)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,5))
plt.plot(df['First Name'].head(15), df['Experience'].head(15),linewidth=0, marker = 'o', color = 'red')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.8/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.8/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'First Name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-58-35c62da3f035> in <module>
#       1 import matplotlib.pyplot as plt
#       2 plt.figure(figsize=(12,5))
# ----> 3 plt.plot(df['First Name'].head(15), df['Experience'].head(15),linewidth=0, marker = 'o', color = 'red')
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'First Name'

# %% [markdown]
# 7. Draw the line plot between age and experience. Observe the trend line.

# %%
import matplotlib.pyplot as plt
plt.plot(df['Age'].head(10), df['Experience'].head(10), marker = 'o', color = 'red')

# %% [markdown]
# 8. Draw the scatter plot between Salary and New_Salary. Observe the correlation

# %%
x = df['Salary']
y = df['New_Salary']
plt.scatter(x, y, c = 'red')
#it is a positive correlation

# %% [markdown]
# 9. Draw the scatter plot between Age and Incentive. Observe the correlation

# %%
x = df['Age']
y = df['Incentive']
plt.scatter(x, y, c = 'red')
#it is a negative correlation

# %% [markdown]
# 10. Draw the box plot to show the statistical summary of Age column and verify with describe()

# %%
plt.boxplot(df['Age']);

# %% [markdown]
# 11. Draw the histogram plot for Experience column

# %%
plt.hist(df['Experience']);

# %% [markdown]
# 12. Draw the histogram plot for Experience column with bin value and PDF

# %%
plt.hist(df['Experience'], edgecolor = 'white', bins = 5, density = True);

# %%
first_100 = temp.head(100)
ans = first_100[first_100['CC'] > 1600] 
print(ans)
# Out:
#     Price  Age      KM FuelType   HP  MetColor  Automatic    CC  Doors  \
# 0   13500   23   46986   Diesel   90         1          0  2000      3
# 1   13750   23   72937   Diesel   90         1          0  2000      3
# 2   13950   24   41711   Diesel   90         1          0  2000      3
# 3   14950   26   48000   Diesel   90         0          0  2000      3
# 4   13750   30   38500   Diesel   90         0          0  2000      3
# 5   12950   32   61000   Diesel   90         0          0  2000      3
# 6   16900   27   94612   Diesel   90         1          0  2000      3
# 7   18600   30   75889   Diesel   90         1          0  2000      3
# 8   21500   27   19700   Petrol  192         0          0  1800      3
# 9   12950   23   71138   Diesel   69         0          0  1900      3
# 10  20950   25   31461   Petrol  192         0          0  1800      3
# 11  19950   22   43610   Petrol  192         0          0  1800      3
# 12  19600   25   32189   Petrol  192         0          0  1800      3
# 13  21500   31   23000   Petrol  192         1          0  1800      3
# 14  22500   32   34131   Petrol  192         1          0  1800      3
# 15  22000   28   18739   Petrol  192         0          0  1800      3
# 16  22750   30   34000   Petrol  192         1          0  1800      3
# 43  16950   27  110404   Diesel   90         0          0  2000      5
# 44  16950   22  100250   Diesel   90         0          0  2000      5
# 45  19000   23   84000   Diesel   90         0          0  2000      5
# 46  17950   27   79375   Diesel   90         1          0  2000      5
# 48  17950   22   72215   Diesel   90         1          0  2000      5
# 49  21950   31   64982   Petrol  192         1          0  1800      5
# 50  17950   22   62636   Diesel   90         1          0  2000      5
# 53  21950   27   49866   Petrol  192         1          0  1800      5
# 68  22250   22   30000   Diesel  110         1          0  2000      5
# 87  17950   20   66966   Diesel   90         1          0  2000      3
# 89  21950   19   50005   Diesel  110         1          0  2000      3
# 91  22250   20   37500   Diesel   90         1          0  2000      3
# 92  19950   16   34472   Diesel   90         1          0  1995      3
# 95  19950   17   30351   Diesel   90         1          0  1995      3
#
#     Weight  Current Price
# 0     1165          27100
# 1     1165          27600
# 2     1165          28000
# 3     1165          30000
# 4     1170          27600
# 5     1170          26000
# 6     1245          33900
# 7     1245          37300
# 8     1185          43100
# 9     1105          26000
# 10    1185          42000
# 11    1185          40000
# 12    1185          39300
# 13    1185          43100
# 14    1185          45100
# 15    1185          44100
# 16    1185          45600
# 43    1255          34000
# 44    1255          34000
# 45    1270          38100
# 46    1255          36000
# 48    1255          36000
# 49    1195          44000
# 50    1255          36000
# 53    1195          44000
# 68    1275          44600
# 87    1245          36000
# 89    1265          44000
# 91    1260          44600
# 92    1260          40000
# 95    1260          40000

# %%
path = 'drive/My Drive/Colab Notebooks/Titanic_visu - Sheet1.csv'
import pandas as pd
df = pd.read_csv(path)
df
# Out:
#     Unnamed: 0  Survived  Pclass           Name     Sex  Age  \
# 0            0         0       3         Braund    male   22
# 1            1         1       1        Cumings  female   38
# 2            2         1       3      Heikkinen  female   26
# 3            3         1       1       Futrelle  female   35
# 4            4         0       3          Allen    male   35
# 5            5         0       3          Moran    male   43
# 6            6         0       1       McCarthy    male   54
# 7            7         0       3        Palsson    male   40
# 8            8         1       3        Johnson  female   27
# 9            9         1       2         Nasser  female   26
# 10          10         1       3      Sandstrom  female   24
# 11          11         1       1        Bonnell  female   58
# 12          12         0       3    Saundercock    male   20
# 13          13         0       3      Andersson    male   39
# 14          14         0       3        Vestrom  female   26
# 15          15         1       2        Hewlett  female   55
# 16          16         0       3           Rice    male   43
# 17          17         1       2       Williams    male   42
# 18          18         0       3  Vander Planke  female   31
# 19          19         1       3     Masselmani  female   23
# 20          20         0       2         Fynney    male   35
# 21          21         1       2        Beesley    male   34
# 22          22         1       3        McGowan  female   52
# 23          23         1       1         Sloper    male   28
# 24          24         0       3        Palsson  female   48
#
#               Ticket     Fare Embarked  Concession   New_Fare
# 0          A/5 21171  53.1000        S        16.1  61.649100
# 1           PC 17599  13.0000        C        17.5  15.275000
# 2   STON/O2. 3101282  31.2750        S        16.4  36.404100
# 3             113803  18.0000        S        17.4  21.132000
# 4             373450  16.7000        S        17.4  19.605800
# 5             330877   8.0500        Q        18.7   9.555350
# 6              17463   7.8542        S        19.5   9.385769
# 7             349909  11.1333        Q        18.0  13.137294
# 8             347742  26.5500        S        16.6  30.957300
# 9             237736  30.0708        C        16.4  35.002411
# 10           PP 9549  35.5000        S        16.3  41.286500
# 11            113783   7.2250        S        20.0   8.670000
# 12         A/5. 2151  71.2833        S        16.0  82.688628
# 13            347082  13.0000        Q        17.8  15.314000
# 14            350406  29.1250        S        16.4  33.901500
# 15            248706   7.2500        S        19.8   8.685500
# 16            382652   8.0500        Q        18.7   9.555350
# 17            244373   8.4583        S        18.3  10.006169
# 18            345763  21.0750        S        17.0  24.657750
# 19              2649  51.8625        C        16.2  60.264225
# 20            239865  16.0000        S        17.4  18.784000
# 21            248698  21.0750        S        17.2  24.699900
# 22            330923   7.9250        Q        19.2   9.446600
# 23            113788  26.0000        S        16.8  30.368000
# 24            349909   8.0292        S        19.0   9.554748

# %%
import matplotlib.pyplot as plt
#plt.figure(figsize=(12,5))
data=df['Embarked'].value_counts()
plt.bar(data.index, data.values, color = ['b', 'r', 'y'])
# Out:
# <BarContainer object of 3 artists>

# %%
import numpy as np
N = 15
plt.figure(figsize = (15, 15))
#see the spelling of arrange
ind = np.arange(N)
width = 0.25 
xval = df['Fare'].head(15)

bar1 = plt.bar(ind, xval, width, color = 'r')
yval = df['New_Fare'].head(15)
bar2 = plt.bar(ind + width, yval, width, color = 'b')

#comparitive charts should always have legends

plt.xlabel('Name')
plt.ylabel('Fare')
plt.xticks(ind + width, df['Name'].head(15))
plt.legend((bar1, bar2),('Fare', 'New_Fare'))

# %%
plt.barh(df['Embarked'],df['Fare'] )
plt.title("Embarked vs Fare")
plt.xlabel("Team")
plt.ylabel("Salary")
# Out:
# Text(0, 0.5, 'Salary')

# %%
plt.figure(figsize=(9,5))
plt.bar(df['Name'].head(10), df['Fare'].head(10))
plt.bar(df['Name'].head(10), df['New_Fare'].head(10), bottom = df['Fare'].head(10))
# Out:
# <BarContainer object of 10 artists>

# %%
ata = df['Pclass'].value_counts()
plt.pie(data.values, labels = data.index, autopct = "%1.1f%%");

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,5))
plt.plot(df['Name'].head(15), df['Age'].head(15),linewidth=0, marker = 'o', color = 'red')

# %%
import matplotlib.pyplot as plt
plt.plot(df['Age'].head(10), df['Concession'].head(10), marker = 'o', color = 'red')

# %%
x = df['Fare']
y = df['New_Fare']
plt.scatter(x, y, c = 'red')
#+ve correlation

# %%
x = df['Age']
y = df['Concession']
plt.scatter(x, y, c = 'red')
#+ve correlation
